# %%
import toytree       # a tree plotting library
import toyplot       # a general plotting library
import numpy as np   # numerical library

from ete3 import Tree

from Bio import Phylo

# %%
tree_loc = '/data11/bio/databases/metaphlan2/mp_genomes_phylophlan3/output_tree/mp_genomes_subset_fna.tre.treefile'

# %%
t = Tree(tree_loc)

# %%
# load a toytree from a newick string at a URL
tre = toytree.tree("https://eaton-lab.org/data/Cyathophora.tre")

# %%
with open(tree_loc, 'r') as tree_f:
    tre = toytree.tree(tree_f)
    print(tre.get_tip_labels())
# Out:
# ['0']

# %%
from Bio import Phylo
tree = Phylo.read(tree_loc, 'newick')
# tree.ladderize()   # Flip branches so deeper clades are displayed at top
# Phylo.draw(tree)

# %%
tree
# Out:
# Tree(rooted=False, weight=1.0)

# %%
# tre = toytree.tree(tree_loc)

# %%
# tre = toytree.tree("https://eaton-lab.org/data/Cyathophora.tre")

# %%
# tre.get_tip_labels()

# %%
newick = "((a:1,b:1)90:3,(c:3,(d:1, e:1)100:2)100:1)100;"
tre0 = toytree.tree(newick, tree_format=0)

# %%
# root and draw the tree (more details on this coming up...)
rtre = tre.root(wildcard="prz")
rtre.draw(tip_labels_align=True);
# Out:
# <div class="toyplot" id="tf933aa51752f46488a8e4b2c83f59d90" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="275.0px" id="t17785f73bb0040bab245d28610d06cdd" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 360.0 275.0" width="360.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tc61e16bba6314ea8b78f5d2b2461d43f"><clipPath id="t47f9af82ce984d9b986e76ba6952fff8"><rect height="215.0" width="300.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t47f9af82ce984d9b986e76ba6952fff8)"><g class="toyplot-mark-Graph" id="tc04b0a1ecf384f7f98ecbac941616ad3"><g class="toyplot-Edges"><path d="M 173.80
# ...
